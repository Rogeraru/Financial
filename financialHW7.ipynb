# %% [markdown]
# <a href="https://colab.research.google.com/github/Rogeraru/Financial/blob/main/financialHW7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#homework7
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/Rogeraru/financial/main/stock_data.csv"
df = pd.read_csv(url, index_col=0)

# %%
df
# Out:
#               Open    High     Low   Close  Adj Close  Volume
# Date
# 2024-01-01  381.72  418.12  378.50  416.65     416.65  189436
# 2024-01-02  115.84  145.06   84.93   98.72      98.72  792954
# 2024-01-03  322.02  335.70  305.68  315.06     315.06  728869
# 2024-01-04  494.02  500.19  462.15  468.52     468.52  629580
# 2024-01-05  361.71  405.07  320.50  362.97     362.97  107266
# ...            ...     ...     ...     ...        ...     ...
# 2024-04-05  298.48  326.56  298.37  314.45     314.45  450858
# 2024-04-06  412.17  448.28  409.48  413.88     413.88  729338
# 2024-04-07  143.29  172.16   99.67  154.33     154.33  159202
# 2024-04-08  304.74  324.55  278.06  294.55     294.55  603633
# 2024-04-09  181.43  227.43  156.61  189.20     189.20  743870
#
# [100 rows x 6 columns]

# %%
df.head(5)
# Out:
#               Open    High     Low   Close  Adj Close  Volume
# Date
# 2024-01-01  381.72  418.12  378.50  416.65     416.65  189436
# 2024-01-02  115.84  145.06   84.93   98.72      98.72  792954
# 2024-01-03  322.02  335.70  305.68  315.06     315.06  728869
# 2024-01-04  494.02  500.19  462.15  468.52     468.52  629580
# 2024-01-05  361.71  405.07  320.50  362.97     362.97  107266

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')
